# %%
from main import create_connection, load_movies_from_db, load_genres_from_db
from main import plot_genre_distribution, plot_release_year_distribution
from main import plot_average_popularity_by_genre, plot_average_vote_count_by_genre
from main import plot_movies_over_time, plot_language_distribution

# %%
# Create a connection to the database
conn = create_connection()
# Out:
# 2.6.0

# %%
# Load movies and genres data from the database
movies_df = load_movies_from_db(conn)
genres_df = load_genres_from_db(conn)

# %% [markdown]
# ### Perform data analysis and visualization

# %%
plot_genre_distribution(movies_df, genres_df)

# %%
plot_release_year_distribution(movies_df)

# %%
plot_average_popularity_by_genre(movies_df, genres_df)

# %%
plot_average_vote_count_by_genre(movies_df, genres_df)

# %%
plot_movies_over_time(movies_df)

# %%
plot_language_distribution(movies_df)

# %%
# Close the connection to the database
conn.close()
